# %%
import pandas as pd
filmes = pd.read_csv('../01.Dados/movies.csv')
filmes.columns = ['filmeId','titulo','generos']
filmes = filmes.set_index('filmeId')
filmes.head(10)
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# 6                               Heat (1995)
# 7                            Sabrina (1995)
# 8                       Tom and Huck (1995)
# 9                       Sudden Death (1995)
# 10                         GoldenEye (1995)
#
#                                              generos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# 6                              Action|Crime|Thriller
# 7                                     Comedy|Romance
# ...

# %%
notas = pd.read_csv('../01.Dados/ratings.csv')
notas.columns = ['usuarioId','filmeId','nota','momento']
notas.head(10)
# Out:
#    usuarioId  filmeId  nota     momento
# 0          1      307   3.5  1256677221
# 1          1      481   3.5  1256677456
# 2          1     1091   1.5  1256677471
# 3          1     1257   4.5  1256677460
# 4          1     1449   4.5  1256677264
# 5          1     1590   2.5  1256677236
# 6          1     1591   1.5  1256677475
# 7          1     2134   4.5  1256677464
# 8          1     2478   4.0  1256677239
# 9          1     2840   3.0  1256677500

# %%
notas.describe()
# Out:
#           usuarioId       filmeId          nota       momento
# count  2.775344e+07  2.775344e+07  2.775344e+07  2.775344e+07
# mean   1.419420e+05  1.848800e+04  3.530445e+00  1.193122e+09
# std    8.170740e+04  3.510263e+04  1.066353e+00  2.160482e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    7.117600e+04  1.097000e+03  3.000000e+00  9.986053e+08
# 50%    1.420220e+05  2.716000e+03  3.500000e+00  1.174256e+09
# 75%    2.124590e+05  7.150000e+03  4.000000e+00  1.422744e+09
# max    2.832280e+05  1.938860e+05  5.000000e+00  1.537945e+09

# %% [markdown]
# # Primeira tentativa de recomendação: heurísitca do total de votos

# %%
## Anliase dos usuários

# %%
total_de_votos = notas['filmeId'].value_counts()
total_de_votos.head()
# Out:
# 318     97999
# 356     97040
# 296     92406
# 593     87899
# 2571    84545
# Name: filmeId, dtype: int64

# %%
filmes['total_de_votos'] = total_de_votos
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos  total_de_votos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy         68469.0
# 2                         Adventure|Children|Fantasy         27143.0
# 3                                     Comedy|Romance         15585.0
# 4                               Comedy|Drama|Romance          2989.0
# 5                                             Comedy         15474.0

# %%
filmes.sort_values('total_de_votos', ascending=False)
# Out:
#                                    titulo                      generos  \
# filmeId
# 318      Shawshank Redemption, The (1994)                  Crime|Drama
# 356                   Forrest Gump (1994)     Comedy|Drama|Romance|War
# 296                   Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 593      Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 2571                   Matrix, The (1999)       Action|Sci-Fi|Thriller
# ...                                   ...                          ...
# 192399                 Under Wraps (1997)       Children|Comedy|Horror
# 192933                       Rosie (2018)                        Drama
# 193109           Ach śpij kochanie (2017)               Crime|Thriller
# 193321                     Pledges (2018)                Comedy|Horror
# 193593           The Happy Thieves (1962)           Comedy|Crime|Drama
#
#          total_de_votos
# filmeId
# 318             97999.0
# 356             97040.0
# ...

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota     momento
# 0          1      307   3.5  1256677221
# 1          1      481   3.5  1256677456
# 2          1     1091   1.5  1256677471
# 3          1     1257   4.5  1256677460
# 4          1     1449   4.5  1256677264

# %%
notas_medias = notas.groupby('filmeId').mean()['nota']
notas_medias.head()
# Out:
# filmeId
# 1    3.886649
# 2    3.246583
# 3    3.173981
# 4    2.874540
# 5    3.077291
# Name: nota, dtype: float64

# %%
filmes['nota_media'] = notas_medias
filmes.sort_values('total_de_votos',ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 318               Shawshank Redemption, The (1994)
# 356                            Forrest Gump (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 527                        Schindler's List (1993)
# 110                              Braveheart (1995)
# 1                                 Toy Story (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 318                                      Crime|Drama         97999.0
# 356                         Comedy|Drama|Romance|War         97040.0
# 296                      Comedy|Crime|Drama|Thriller         92406.0
# 593                            Crime|Horror|Thriller         87899.0
# ...

# %% [markdown]
# # Um segunda heurística: nota média pela a quantidade de votos

# %%
filmes.sort_values('nota_media',ascending = False).head(10)
# Out:
#                                             titulo               generos  \
# filmeId
# 169338          Brad Williams: Daddy Issues (2016)                Comedy
# 187729                     Ab-normal Beauty (2004)                Horror
# 172149                   Back to You and Me (2005)         Drama|Romance
# 160966   You're Human Like the Rest of Them (1967)    (no genres listed)
# 134387                       At Ellen’s Age (2011)          Comedy|Drama
# 98437                          Bed of Roses (1933)  Comedy|Drama|Romance
# 134433                     Le nuove comiche (1994)    (no genres listed)
# 172151            The Shocking Miss Pilgrim (1947)        Comedy|Romance
# 134605                        Men Don't Cry (1968)                Comedy
# 134633                              Tony 10 (2012)              Children
#
#          total_de_votos  nota_media
# filmeId
# 169338              2.0         5.0
# 187729              1.0         5.0
# ...

# %%
filmes.query('total_de_votos >=10').sort_values('nota_media',ascending=False).head(10)
# Out:
#                                           titulo  \
# filmeId
# 171705                          Den radio (2001)
# 171011                    Planet Earth II (2016)
# 159817                       Planet Earth (2006)
# 318             Shawshank Redemption, The (1994)
# 170705                   Band of Brothers (2001)
# 191999               The Reichenbach Fall (2012)
# 174053      Black Mirror: White Christmas (2014)
# 171495                                    Cosmos
# 172591   The Godfather Trilogy: 1972-1990 (1992)
# 858                        Godfather, The (1972)
#
#                                       generos  total_de_votos  nota_media
# filmeId
# 171705                     (no genres listed)            13.0    4.576923
# 171011                            Documentary           853.0    4.486518
# 159817                            Documentary          1384.0    4.458092
# 318                               Crime|Drama         97999.0    4.424188
# ...

# %%
total_com_media_de_50 = filmes.query('total_de_votos >=50')
total_com_media_de_50.sort_values('nota_media',ascending=False).head(10)
# Out:
#                                           titulo  \
# filmeId
# 171011                    Planet Earth II (2016)
# 159817                       Planet Earth (2006)
# 318             Shawshank Redemption, The (1994)
# 170705                   Band of Brothers (2001)
# 174053      Black Mirror: White Christmas (2014)
# 171495                                    Cosmos
# 172591   The Godfather Trilogy: 1972-1990 (1992)
# 858                        Godfather, The (1972)
# 50                    Usual Suspects, The (1995)
# 176601                              Black Mirror
#
#                                       generos  total_de_votos  nota_media
# filmeId
# 171011                            Documentary           853.0    4.486518
# 159817                            Documentary          1384.0    4.458092
# 318                               Crime|Drama         97999.0    4.424188
# 170705                       Action|Drama|War           984.0    4.399898
# ...

# %%
eu_assisti = [1,21,19,11,7,2]
filmes.loc[eu_assisti]
# Out:
#                                         titulo  \
# filmeId
# 1                             Toy Story (1995)
# 21                           Get Shorty (1995)
# 19       Ace Ventura: When Nature Calls (1995)
# 11              American President, The (1995)
# 7                               Sabrina (1995)
# 2                               Jumanji (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy         68469.0
# 21                             Comedy|Crime|Thriller         25699.0
# 19                                            Comedy         24913.0
# 11                              Comedy|Drama|Romance         19669.0
# 7                                     Comedy|Romance         15301.0
# 2                         Adventure|Children|Fantasy         27143.0
#
#          nota_media
# filmeId
# 1          3.886649
# 21         3.568368
# 19         2.642014
# 11         3.660278
# ...

# %%
aventura_infantil_e_fantasia = total_com_media_de_50.query("generos == 'Adventure|Children|Fantasy'")
aventura_infantil_e_fantasia.drop(eu_assisti, errors='ignore').sort_values('nota_media',ascending=False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 4896     Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 80748                           Alice in Wonderland (1933)
# 2161                         NeverEnding Story, The (1984)
# 50601                          Bridge to Terabithia (2007)
# 41566    Chronicles of Narnia: The Lion, the Witch and ...
# 82169    Chronicles of Narnia: The Voyage of the Dawn T...
# 2043             Darby O'Gill and the Little People (1959)
# 59501     Chronicles of Narnia: Prince Caspian, The (2008)
# 56915          Water Horse: Legend of the Deep, The (2007)
# 160573                                Pete's Dragon (2016)
#
#                             generos  total_de_votos  nota_media
# filmeId
# 4896     Adventure|Children|Fantasy         27434.0    3.674892
# 80748    Adventure|Children|Fantasy           117.0    3.564103
# 2161     Adventure|Children|Fantasy         12426.0    3.500161
# ...

# %%
#Tipos de recomendacao = Collaborative filtering,Content based filtering e várias outras

# %% [markdown]
# # Outras abordagem de recomendação: procurar usuários 'similares'

# %%
from math import sqrt
import numpy as np
def pitagoras(a,b):
    (delta_x, delta_y) = a - b
    return sqrt(delta_x**2 + delta_y**2)
joao = np.array([4,4.5])
maria = np.array([5,5])
pitagoras(joao,maria)
# Out:
# 1.118033988749895

# %%
np.linalg.norm(joao-maria)
# Out:
# 1.118033988749895

# %%
def notas_do_usuario(usuario):
    notas_do_usuario = notas.query('usuarioId==%d' % usuario)
    notas_do_usuario = notas_do_usuario[['filmeId','nota']].set_index('filmeId')
    return notas_do_usuario

# %%
usr1 = notas_do_usuario(1)
usr1
# Out:
#          nota
# filmeId
# 307       3.5
# 481       3.5
# 1091      1.5
# 1257      4.5
# 1449      4.5
# 1590      2.5
# 1591      1.5
# 2134      4.5
# 2478      4.0
# 2840      3.0
# 2986      2.5
# 3020      4.0
# 3424      4.5
# 3698      3.5
# 3826      2.0
# 3893      3.5

# %%
usr4 = notas_do_usuario(4)
usr4
# Out:
#          nota
# filmeId
# 1         4.0
# 2         4.0
# 5         2.0
# 6         4.5
# 10        4.0
# ...       ...
# 53972     3.5
# 53996     4.5
# 54286     5.0
# 55765     4.5
# 56367     4.5
#
# [736 rows x 1 columns]

# %%
diferencas = usr1.join(usr4,lsuffix='_esquerda',rsuffix='_direita').dropna()
diferencas['nota_esquerda']
# Out:
# filmeId
# 481     3.5
# 1091    1.5
# 1590    2.5
# 1591    1.5
# 2478    4.0
# 2840    3.0
# 2986    2.5
# 3020    4.0
# 3698    3.5
# 3826    2.0
# Name: nota_esquerda, dtype: float64

# %% [markdown]
# # Distância do usuário no dataset

# %%
diferencas['nota_direita']
# Out:
# filmeId
# 481     4.0
# 1091    1.0
# 1590    3.5
# 1591    3.5
# 2478    3.0
# 2840    3.5
# 2986    1.5
# 3020    3.5
# 3698    4.0
# 3826    3.0
# Name: nota_direita, dtype: float64

# %%
def distancia_de_vetores(a,b):
    return np.linalg.norm(a - b)

# %%
distancia_de_vetores(diferencas['nota_direita'],diferencas['nota_esquerda'])
# Out:
# 3.0413812651491097

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2,lsuffix='_esquerda',rsuffix='_direita').dropna()
    distancia = distancia_de_vetores(diferencas['nota_direita'],diferencas['nota_esquerda'])
    return [usuario_id1,usuario_id2,distancia]
distancia_de_usuarios(1,4)
# Out:
# [1, 4, 3.0413812651491097]

# %%
notas['usuarioId'].unique()
# Out:
# array([     1,      2,      3, ..., 283226, 283227, 283228])

# %%
len(notas['usuarioId'].unique())
# Out:
# 283228

# %%
quantidade_de_usuarios = len(notas['usuarioId'].unique())
print("Temos %d usuarios" % quantidade_de_usuarios)
# Out:
# Temos 283228 usuarios

# %%
vc_id = 1
distancia = []
for usuario_id in notas['usuarioId'].unique():
    informacoes = distancia_de_usuarios(vc_id,usuario_id)
    distancia.append(informacoes)
distancia[:5]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-fa4131b3a7ce> in <module>
#       2 distancia = []
#       3 for usuario_id in notas['usuarioId'].unique():
# ----> 4     informacoes = distancia_de_usuarios(vc_id,usuario_id)
#       5     distancia.append(informacoes)
#       6 distancia[:5]
#
# <ipython-input-80-d1e86da70dc7> in distancia_de_usuarios(usuario_id1, usuario_id2)
#       1 def distancia_de_usuarios(usuario_id1, usuario_id2):
# ----> 2     notas1 = notas_do_usuario(usuario_id1)
#       3     notas2 = notas_do_usuario(usuario_id2)
#       4     diferencas = notas1.join(notas2,lsuffix='_esquerda',rsuffix='_direita').dropna()
#       5     distancia = distancia_de_vetores(diferencas['nota_direita'],diferencas['nota_esquerda'])
#
# <ipython-input-52-7db82d43a9a5> in notas_do_usuario(usuario)
#       1 def notas_do_usuario(usuario):
# ...

# %%
def distancia_de_todos(vc_id):
    distancia = []
    for usuario_id in notas['usuarioId'].unique():
        informacoes = distancia_de_usuarios(vc_id,usuario_id)
        distancia.append(informacoes)
    return distancia
distancia_de_todos(1)[:5]

# %%
def distancia_de_todos(vc_id):
    todos_os_usuarios = notas['usuarioId'].unique()
    distancias = [distancia_de_usuarios(vc_id,usuario_id) for usuario_id in todos_os_usuarios]
    distancias = pd.DataFrame(distancias, columns=['voce','outra_pessoa','distancia'])
    return distancias

# %% [markdown]
# # Usuários sem nada em comum são colocados bem distante um do outro

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2,minimo=5):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2,lsuffix='_esquerda',rsuffix='_direita').dropna()
    if (len(diferencas < minimo)):
        return [usuario_id1, usuario_id2,100000]
    distancia = distancia_de_vetores(diferencas['nota_direita'],diferencas['nota_esquerda'])
    return [usuario_id1,usuario_id2,distancia]
distancia_de_usuarios(1,4)
# Out:
# [1, 4, 100000]

# %%
def mais_proximos(vc):
    distancias = distancia_de_todos(vc)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(vc)
    return distancias

# %%
mais_proximos(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-4f105bb763f6> in <module>
# ----> 1 mais_proximos(1)
#
# <ipython-input-96-bcc69570e227> in mais_proximos(vc)
#       1 def mais_proximos(vc):
# ----> 2     distancias = distancia_de_todos(vc)
#       3     return distancias.sort_values('distancia')
#
# <ipython-input-95-30fadef63ff4> in distancia_de_todos(vc_id)
#       1 def distancia_de_todos(vc_id):
#       2     todos_os_usuarios = notas['usuarioId'].unique()
# ----> 3     distancias = [distancia_de_usuarios(vc_id,usuario_id) for usuario_id in todos_os_usuarios]
#       4     distancias = pd.DataFrame(distancias, columns=['voce','outra_pessoa','distancia'])
#       5     return distancias
#
# <ipython-input-95-30fadef63ff4> in <listcomp>(.0)
#       1 def distancia_de_todos(vc_id):
#       2     todos_os_usuarios = notas['usuarioId'].unique()
# ...

# %% [markdown]
# # Parâmetros para teste

# %%
def mais_proximos_de(vc_id,n_mais_proximos,numero_de_usuarios_a_analisar= None):
    distancias = distancia_de_todos(vc_id,numero_de_usuarios_a_analisar=numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(vc_id)
    return distancias

# %%
def distancia_de_todos(vc_id, numero_de_usuarios_a_analisar = None):
    todos_os_usuarios = notas['usuarioId'].unique()
    if numero_de_usuarios_a_analisar:
        todos_os_usuarios = todos_os_usuarios[:numero_de_usuarios_a_analisar]
    distancias = [distancia_de_usuarios(vc_id,usuario_id) for usuario_id in todos_os_usuarios]
    distanciaas = list(filter(None,distancias))
    distancias = pd.DataFrame(distancias, columns = ['voce','outra_pessoa','distancia'])
    return distancia

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2,minimo=5):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2,lsuffix='_esquerda',rsuffix='_direita').dropna()
    if (len(diferencas < minimo)):
        return None
    distancia = distancia_de_vetores(diferencas['nota_direita'],diferencas['nota_esquerda'])
    return [usuario_id1,usuario_id2,distancia]

# %%
mais_proximos_de(1,numero_de_usuarios_a_analisar=50)

# %%
def sugere_para(voce, numero_de_usuarios_a_analisar=None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce = notas_de_voce.index
    
    similares = mais_proximos_de(voce, numero_de_usuarios_a_analisar = 50)
    similares = similares.iloc[0].name
    notas_do_similar = notas_do_usuario(similar)
    notas_do_similar = notas_do_similar.drop(filmes_que_voce_ja_viu, errors='ignore')
    recomendacoes = notas_do_similar.sort_values('nota',ascending=False)
    return recomendacoes.join(filmes)

# %%
sugere_para(1).head()

# %% [markdown]
# # Sugerindo baseado em vários usuários

# %%
def sugere_para(voce,n_mais_proximos=10,numero_de_usuarios_a_analisar=None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index
    similares = knn(voce, n_mais_proximos)
    usuarios_similares = similares.index
    notas_dos_similares = notas.set_index('usuarioId').loc[usuarios_similares]
    recomendacoes = notas_dos_similares.groupby('filmeId').mean()[['nota']]
    recomendacoes = recomendacoes.sort_values('nota', ascending=False)
    return recomendacoes.join(filmes)

# %%
def knn(voce_id, k = 10, numero_de_usuarios_a_analisar = None):
    distancia = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar=numero_de_usuarios_a_analisar)
    distancia = distancia.sort_values("distancia")
    distancia = distancia.set_index('outra_pessoa').drop(voce_id,errors='ignore')
    return distancias.head(k)

# %%
voce = 1
n_mais_proximos = 10
numeros_de_usuarios_a_analisar = 50
sugere_para(1,numeros_de_usuarios_a_analisar)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-641241eab39b> in <module>
#       2 n_mais_proximos = 10
#       3 numeros_de_usuarios_a_analisar = 50
# ----> 4 sugere_para(1,numeros_de_usuarios_a_analisar)
#
# <ipython-input-146-9226add00bfe> in sugere_para(voce, n_mais_proximos, numero_de_usuarios_a_analisar)
#       2     notas_de_voce = notas_do_usuario(voce)
#       3     filmes_que_voce_ja_viu = notas_de_voce.index
# ----> 4     similares = knn(voce, n_mais_proximos)
#       5     usuarios_similares = similares.index
#       6     notas_dos_similares = notas.set_index('usuarioId').loc[usuarios_similares]
#
# <ipython-input-145-1c960c730248> in knn(voce_id, k, numero_de_usuarios_a_analisar)
#       1 def knn(voce_id, k = 10, numero_de_usuarios_a_analisar = None):
# ...

# %% [markdown]
# # Testa um usuário novo

# %%
filmes.loc[[122904,1246,2529,2329,2324,1,7,2,1196,260]]

# %%
def novo_usuario(dados):
    novo_usuario = notas['usuarioId'].max()+1
    notas_do_usuario_novo = pd.DataFrame(dados, columns=['filmeId','nota'])
    notas_do_usuario_novo['usuarioId'] = novo_usuario
    return pd.concat([notas, notas_do_usuario_novo])

# %%
sugere_para(8621).head()

# %% [markdown]
# # Utilizar somente as notas filmes com mais de 50 votos

# %%
notasnotas.set_index('filmeId').loc(filmes_com_mais_de_50_votos.index)
notas.head()

# %%
notas = notas.reset_index()
notas.head()

# %%
def sugere_para(voce,k_mais_proximos = 10,numero_de_usuarios_a_analisar = None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index
    
    similares = knn(voce, k_mais_proximos=k_mais_proximos,numero_de_usuarios_a_analisar=numero_de_usuarios_a_analisar) )
    usuarios_similares = similares.index
    notas_dos_similares = notas.set_index('usuarioId').loc[usuarios_similares]
    recomendacoes = notas_dos_similares.groupby('filmeId').mean()[['nota']]
    aparicoes = notas_dos_similares.groupby('filmeId').concat()['nota']
    
    filto_minimo = k_mais_proximos /2
    recomendacoes = recomendacoes.join(aparicoes, lsuffix='_media_dos_usuarios', rsuffix='_aparicoes_nos_usuarios')
    recomendacoes = recomendacoes.query('nota_aparicoes_nos_usuarios >= %.2f'% filtro_minimo) 
    recomendacoes = recomendacoes.sort_values('nota_media_dos_usuarios',ascending=False)
    recomendacoes = recomendacoes.drop(filmes_que_voce_ja_viu, errors='ignore')
    
    return recomendacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar=500)

# %%
sugere_para(8621, k_mais_proximos=20).head(10)
